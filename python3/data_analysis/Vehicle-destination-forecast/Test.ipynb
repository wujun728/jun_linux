# %%
import requests
import pandas as pd

url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# 我们可以发一个HTTP GET请求，使用requests扩展库：
resp = requests.get(url);

# 响应对象的json方法会返回一个包含被解析过的JSON字典，加载到一个Python对象中：
data = resp.json();

title = data[0]['title']

print(title)

# data中的每个元素都是一个包含所有GitHub主题页数据（不包含评论）的字典。我们可以直接传递数据到DataFrame，并提取感兴趣的字段：

issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
print(issues);
# Out:
# read_sas column limit
#     number                                              title  \
# 0    24794                              read_sas column limit
# 1    24793  Avoid unnecessary use of _coerce_scalar_to_tim...
# 2    24790  Bug: plot.bar() plots very incorrect values fo...
# 3    24789             Crosstab Preserves Dtypes release note
# 4    24788  Timestamp.strftime() has erratic behavior afte...
# 5    24787  How to force pandas to display all columns on ...
# 6    24786  df.groupby(df.index) drops index info when df ...
# 7    24784                            Locators off by one day
# 8    24783  Single-level tuple index to multi-level index ...
# 9    24782  BUG: DataFrame.merge(suffixes=) does not respe...
# 10   24779               python-project-packaging-with-pandas
# 11   24778  Python crash with segmentation failure upon im...
# 12   24775                BUG: timedelta64 + Timestamp raises
# 13   24773                    ExtensionArray.astype docstring
# 14   24769             REF/TST: Stop using singleton fixtures
# 15   24768  Concatenating rows with Int64 datatype coerces...
# 16   24767  The feather example from docs segfault with py...
# 17   24766        read_html ignores paragraphs in table cells
# 18   24763              Format mismatch doesn't coerce to NaT
# 19   24762                           DOC: update DF.set_index
# 20   24757  implement+test mean for datetimelike EA/Index/...
# 21   24753     [0.24.0rc1] passing dtype='M8' to Index raises
# 22   24752  DataFrame.mean includes datetime64[ns] dtypes ...
# 23   24749                       Split test_excel.py (#24472)
# 24   24748  ENH / RFC Only apply first row once in fast apply
# 25   24742  23 seems to be the new 42: exception if concat...
# 26   24740     Exception when grouping on a modified category
# 27   24739  0.24.0rc1: infer_dtype(DatetimeIndex) returns ...
# 28   24737  PERF: leverage tzlocal package to provide 2000...
# 29   24736  TST: add  coverage of DST transition for DateT...
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# 2   [{'id': 2413328, 'node_id': 'MDU6TGFiZWwyNDEzM...  open
# 3   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 4   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 5                                                  []  open
# 6                                                  []  open
# 7                                                  []  open
# 8                                                  []  open
# 9   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 10                                                 []  open
# 11  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 12  [{'id': 47223669, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 13  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 14  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 15  [{'id': 195647922, 'node_id': 'MDU6TGFiZWwxOTU...  open
# 16  [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 17  [{'id': 57395487, 'node_id': 'MDU6TGFiZWw1NzM5...  open
# 18  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 19  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 20  [{'id': 57296398, 'node_id': 'MDU6TGFiZWw1NzI5...  open
# 21  [{'id': 31404521, 'node_id': 'MDU6TGFiZWwzMTQw...  open
# 22  [{'id': 47223669, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 23  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 24  [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNj...  open
# 25  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 27  [{'id': 31404521, 'node_id': 'MDU6TGFiZWwzMTQw...  open
# 28  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 29  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
