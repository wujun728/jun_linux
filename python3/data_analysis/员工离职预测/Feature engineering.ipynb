# %%
import pandas as pd
import numpy as np

# %%
pf = pd.read_csv('data/pfm_test.csv')

# %%
pf.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   40         Non-Travel  Research & Development                 9
# 1   53      Travel_Rarely  Research & Development                 7
# 2   42      Travel_Rarely  Research & Development                 2
# 3   34  Travel_Frequently         Human Resources                11
# 4   32      Travel_Rarely  Research & Development                 1
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          4          Other            1449                        3    Male
# 1          2        Medical            1201                        4  Female
# 2          4          Other             477                        1    Male
# 3          3  Life Sciences            1289                        3    Male
# 4          1  Life Sciences             134                        4    Male
#
#    JobInvolvement          ...           RelationshipSatisfaction  \
# ...

# %%
pf.describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeNumber  \
# count  350.000000        350.000000  350.000000      350.000000
# mean    36.471429          8.391429    2.868571     1023.285714
# std      9.373378          7.685318    1.029583      612.566819
# min     18.000000          1.000000    1.000000        2.000000
# 25%     30.000000          2.000000    2.000000      463.250000
# 50%     35.000000          7.000000    3.000000     1011.000000
# 75%     42.000000         11.000000    4.000000     1584.500000
# max     60.000000         29.000000    5.000000     2068.000000
#
#        EnvironmentSatisfaction  JobInvolvement    JobLevel  JobSatisfaction  \
# count               350.000000      350.000000  350.000000       350.000000
# mean                  2.714286        2.734286    2.068571         2.725714
# std                   1.067129        0.726669    1.089615         1.083437
# min                   1.000000        1.000000    1.000000         1.000000
# ...

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 30 columns):
# Age                         350 non-null int64
# BusinessTravel              350 non-null object
# Department                  350 non-null object
# DistanceFromHome            350 non-null int64
# Education                   350 non-null int64
# EducationField              350 non-null object
# EmployeeNumber              350 non-null int64
# EnvironmentSatisfaction     350 non-null int64
# Gender                      350 non-null object
# JobInvolvement              350 non-null int64
# JobLevel                    350 non-null int64
# JobRole                     350 non-null object
# JobSatisfaction             350 non-null int64
# MaritalStatus               350 non-null object
# MonthlyIncome               350 non-null int64
# NumCompaniesWorked          350 non-null int64
# Over18                      350 non-null object
# ...

# %%
sex_mapDict={'Male':1,
            'Female':0}
    


pf['Gender']=pf['Gender'].map(sex_mapDict)
pf.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   40         Non-Travel  Research & Development                 9
# 1   53      Travel_Rarely  Research & Development                 7
# 2   42      Travel_Rarely  Research & Development                 2
# 3   34  Travel_Frequently         Human Resources                11
# 4   32      Travel_Rarely  Research & Development                 1
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          4          Other            1449                        3       1
# 1          2        Medical            1201                        4       0
# 2          4          Other             477                        1       1
# 3          3  Life Sciences            1289                        3       1
# 4          1  Life Sciences             134                        4       1
#
#    JobInvolvement          ...           RelationshipSatisfaction  \
# ...

# %%
pf['BusinessTravel'].groupby(pf['BusinessTravel']).count()
# Out:
# BusinessTravel
# Non-Travel            39
# Travel_Frequently     67
# Travel_Rarely        244
# Name: BusinessTravel, dtype: int64

# %%
BusinessTravel_mapDict={'Non-Travel':0,
                       'Travel_Frequently':1,
                       'Travel_Rarely':2}

pf['BusinessTravel']=pf['BusinessTravel'].map(BusinessTravel_mapDict)

# %%
pf['Department'].groupby(pf['Department']).count()
# Out:
# Department
# Human Resources            21
# Research & Development    219
# Sales                     110
# Name: Department, dtype: int64

# %%
Department_mapDict={'Human Resources':0,
                       'Research & Development':1,
                       'Sales':2}

pf['Department']=pf['Department'].map(Department_mapDict)

# %%
pf.head()
# Out:
#    Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   40               0           1                 9          4
# 1   53               2           1                 7          2
# 2   42               2           1                 2          4
# 3   34               1           0                11          3
# 4   32               2           1                 1          1
#
#   EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          Other            1449                        3       1
# 1        Medical            1201                        4       0
# 2          Other             477                        1       1
# 3  Life Sciences            1289                        3       1
# 4  Life Sciences             134                        4       1
#
#    JobInvolvement          ...           RelationshipSatisfaction  \
# 0               3          ...                                  3
# ...

# %%
pf['EducationField'].groupby(pf['EducationField']).count()
# Out:
# EducationField
# Human Resources       8
# Life Sciences       133
# Marketing            31
# Medical             122
# Other                18
# Technical Degree     38
# Name: EducationField, dtype: int64

# %%
EducationField_mapDict={'Human Resources':4,
                        'Life Sciences':1,
                        'Marketing':2,
                        'Medical':3,
                        'Other':0,
                        'Technical Degree':5}

pf['EducationField']=pf['EducationField'].map(EducationField_mapDict)

# %%
pf.drop(columns=['Over18'], axis=0)#都年满18
# Out:
#      Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0     40               0           1                 9          4
# 1     53               2           1                 7          2
# 2     42               2           1                 2          4
# 3     34               1           0                11          3
# 4     32               2           1                 1          1
# 5     45               2           0                 4          3
# 6     32               2           2                 1          4
# 7     38               2           1                25          2
# 8     37               2           1                 1          3
# 9     29               1           2                 1          1
# 10    41               1           1                 9          3
# 11    30               0           2                25          2
# 12    24               1           1                 9          3
# ...

# %%
pf['Department'].groupby(pf['Department']).count()
# Out:
# Department
# 0     21
# 1    219
# 2    110
# Name: Department, dtype: int64

# %%
pf['OverTime'].groupby(pf['OverTime']).count()
# Out:
# OverTime
# No     241
# Yes    109
# Name: OverTime, dtype: int64

# %%
sex_mapDict={'Yes':1,
            'No':0}
    


pf['OverTime']=pf['OverTime'].map(sex_mapDict)
pf.head()
# Out:
#    Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   40               0           1                 9          4
# 1   53               2           1                 7          2
# 2   42               2           1                 2          4
# 3   34               1           0                11          3
# 4   32               2           1                 1          1
#
#    EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0               0            1449                        3       1
# 1               3            1201                        4       0
# 2               0             477                        1       1
# 3               1            1289                        3       1
# 4               1             134                        4       1
#
#    JobInvolvement          ...           RelationshipSatisfaction  \
# 0               3          ...                                  3
# ...

# %%
pf['OverTime'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: OverTime, dtype: int64

# %%
pf.head(50)
# Out:
#     Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0    40               0           1                 9          4
# 1    53               2           1                 7          2
# 2    42               2           1                 2          4
# 3    34               1           0                11          3
# 4    32               2           1                 1          1
# 5    45               2           0                 4          3
# 6    32               2           2                 1          4
# 7    38               2           1                25          2
# 8    37               2           1                 1          3
# 9    29               1           2                 1          1
# 10   41               1           1                 9          3
# 11   30               0           2                25          2
# 12   24               1           1                 9          3
# ...

# %%
pf['JobRole'].groupby(pf['JobRole']).count()
# Out:
# JobRole
# Healthcare Representative    27
# Human Resources              19
# Laboratory Technician        50
# Manager                      20
# Manufacturing Director       41
# Research Director            22
# Research Scientist           69
# Sales Executive              76
# Sales Representative         26
# Name: JobRole, dtype: int64

# %%
JobRole_mapDict={'Healthcare Representative':0,
                        'Human Resources':1,
                        'Laboratory Technician':2,
                        'Manager':3,
                        'Manufacturing Director':4,
                        'Research Director':5,
                        'Research Scientist':6,
                        'Sales Executive':7,
                        'Sales Representative':8,}

pf['JobRole']=pf['JobRole'].map(JobRole_mapDict)

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 30 columns):
# Age                         350 non-null int64
# BusinessTravel              350 non-null int64
# Department                  350 non-null int64
# DistanceFromHome            350 non-null int64
# Education                   350 non-null int64
# EducationField              350 non-null int64
# EmployeeNumber              350 non-null int64
# EnvironmentSatisfaction     350 non-null int64
# Gender                      350 non-null int64
# JobInvolvement              350 non-null int64
# JobLevel                    350 non-null int64
# JobRole                     350 non-null int64
# JobSatisfaction             350 non-null int64
# MaritalStatus               350 non-null object
# MonthlyIncome               350 non-null int64
# NumCompaniesWorked          350 non-null int64
# Over18                      350 non-null object
# OverTime                    350 non-null int64
# ...

# %%
pf['MaritalStatus'].groupby(pf['MaritalStatus']).count()
# Out:
# MaritalStatus
# Divorced     85
# Married     163
# Single      102
# Name: MaritalStatus, dtype: int64

# %%
MaritalStatus_mapDict={'Divorced':1,
                       'Married':2,
                       'Single':0}
     


pf['MaritalStatus']=pf['MaritalStatus'].map(MaritalStatus_mapDict)

# %%
pf['Over18'].groupby(pf['Over18']).count()
# Out:
# Over18
# Y    350
# Name: Over18, dtype: int64

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 30 columns):
# Age                         350 non-null int64
# BusinessTravel              350 non-null int64
# Department                  350 non-null int64
# DistanceFromHome            350 non-null int64
# Education                   350 non-null int64
# EducationField              350 non-null int64
# EmployeeNumber              350 non-null int64
# EnvironmentSatisfaction     350 non-null int64
# Gender                      350 non-null int64
# JobInvolvement              350 non-null int64
# JobLevel                    350 non-null int64
# JobRole                     350 non-null int64
# JobSatisfaction             350 non-null int64
# MaritalStatus               350 non-null int64
# MonthlyIncome               350 non-null int64
# NumCompaniesWorked          350 non-null int64
# Over18                      350 non-null object
# OverTime                    350 non-null int64
# ...

# %%
Over18_mapDict={'Y':0}
     


pf['Over18']=pf['Over18'].map(Over18_mapDict)

# %%
pf.to_csv('data/FEtest.csv',index=False)
